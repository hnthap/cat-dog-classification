# %% [markdown]
# # Inference Notebook: Cat-Dog Image Classification
#
# Author: **hnthap**

# %%
import os
from PIL import Image
import matplotlib.pyplot as plt

# %%
os.chdir('..')

# %%
image_path = './images/may.jpg'

# !python infer.py "{image_path}" > out.txt

with open('out.txt', 'rt') as f:
    plt.title('Image: %s\nPrediction: %s' % (image_path, ''.join(f.readlines()).strip()))
    with Image.open(image_path).convert('RGB') as image:
        plt.imshow(image)
    plt.show()

# %%
image_path = './images/dog.jpg'

# !python infer.py "{image_path}" > out.txt

with open('out.txt', 'rt') as f:
    plt.title('Image: %s\nPrediction: %s' % (image_path, ''.join(f.readlines()).strip()))
    with Image.open(image_path).convert('RGB') as image:
        plt.imshow(image)
    plt.show()

# %%
image_path = './images/fbi_dog_dolce.jpg'

# !python infer.py "{image_path}" > out.txt

with open('out.txt', 'rt') as f:
    plt.title('Image: %s\nPrediction: %s' % (image_path, ''.join(f.readlines()).strip()))
    with Image.open(image_path).convert('RGB') as image:
        plt.imshow(image)
    plt.show()
