# %% [markdown]
# # Inference Notebook: Cat-Dog Image Classification
#
# Author: **hnthap**

# %%
import os
from IPython import display

os.chdir('..')

# %%
image_path = './data/PetImages/Cat/100.jpg'

# !python infer.py "{image_path}"

display.Image(image_path)
# Out:
# CUDA Device: NVIDIA GeForce RTX 3050 Laptop GPU
# Model loaded: ./checkpoint/ckpt-a-20250314-092618-383242.pth
# Predicted: Cat

# %%
image_path = './data/PetImages/Dog/1000.jpg'

# !python infer.py "{image_path}"

display.Image(image_path)
# Out:
# CUDA Device: NVIDIA GeForce RTX 3050 Laptop GPU
# Model loaded: ./checkpoint/ckpt-a-20250314-092618-383242.pth
# Predicted: Dog
